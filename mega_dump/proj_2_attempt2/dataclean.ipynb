# %% [markdown]
# ## File to clean BIOtaggedForNER.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('BIOtaggedForNER.csv')

# %%
data
# Out:
#                     C1            C2           C3             C4         C5  \
# 0             Patients          with      Crohn's        disease  exhibited
# 1                ['O',           O',  B-DISEASE',    I-DISEASE',        O',
# 2                  NaN           NaN          NaN            NaN        NaN
# 3                  The    antibiotic    treatment  significantly    altered
# 4                ['O',   B-PROCESS',  I-PROCESS',            O',        O',
# ..                 ...           ...          ...            ...        ...
# 292           Systemic  mastocytosis     patients         showed  increased
# 293      ['B-DISEASE',   I-DISEASE',          O',            O',        O',
# 294                NaN           NaN          NaN            NaN        NaN
# 295  Graft-versus-host       disease     involved       enhanced      donor
# 296      ['B-DISEASE',   I-DISEASE',          O',            O',        O',
#
# ...
