# %%
# !nvidia-smi
# Out:
# Thu Apr  9 13:15:10 2026
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.261.03             Driver Version: 535.261.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  | 00000000:19:00.0 Off |                    0 |
# | N/A   42C    P0             121W / 700W |  30453MiB / 81559MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
    repo_id="Jackrong/Qwen3.5-27B-Claude-4.6-Opus-Reasoning-Distilled-GGUF",
    filename="*Q4_K_M.gguf",
    n_ctx=24576,
    n_gpu_layers=-1,  # offload all layers to GPU
    verbose=False,
)
print("model loaded")
# Out:
# llama_context: n_ctx_seq (24576) < n_ctx_train (262144) -- the full capacity of the model will not be utilized
# model loaded

# %%
#testing the big daddy model

# %%
output = llm.create_chat_completion(
    messages=[{"role": "user", "content": "Extract microbe-disease relationships: Patients with Crohn's disease showed reduced Faecalibacterium prausnitzii (p<0.01). Return JSON only."}],
    temperature=0,
    max_tokens=512,
)
print(output["choices"][0]["message"]["content"])
# Out:
# Let me analyze the given text to extract microbe-disease relationships:
#
# Text: "Patients with Crohn's disease showed reduced Faecalibacterium prausnitzii (p<0.01)."
#
# Step 1: Identify the disease
# - "Crohn's disease" is clearly mentioned as the disease condition
#
# Step 2: Identify the microbe
# - "Faecalibacterium prausnitzii" is a bacterium (microbe)
#
# Step 3: Determine the relationship
# - The text states that patients with Crohn's disease "showed reduced" levels of this microbe
# - This indicates a negative association - the microbe is decreased in the disease state
# - The p-value (p<0.01) indicates statistical significance
#
# Step 4: Format as JSON
# - I need to create a JSON structure that captures:
#   - The disease name
#   - The microbe name
#   - The type of relationship (reduced/decreased)
#   - The statistical significance
#
# The relationship can be described as:
# - Disease: Crohn's disease
# - Microbe: Faecalibacterium prausnitzii
# - Relationship: reduced (negative association)
# - Significance: p<0.01
# </think>
#
# ```json
# {
#   "relationships": [
#     {
#       "disease": "Crohn's disease",
#       "microbe": "Faecalibacterium prausnitzii",
#       "relationship_type": "reduced",
#       "direction": "negative",
#       "p_value": "<0.01",
#       "description": "Faecalibacterium prausnitzii levels are reduced in patients with Crohn's disease"
#     }
#   ]
# }
# ```

# %%
#running the same prompt from the llama version

# %%
#original prompt
'''
PROMPT_TEMPLATE = """Extract all microbe-disease relationships from this paper.

For each microbe with a reported change, record:
- taxon_name: exact name from the paper
- direction: "increased" or "decreased"

Return ONLY valid JSON:
{{"disease": "disease name", "taxa_enriched": ["taxon1", "taxon2"], "taxa_depleted": ["taxon3", "taxon4"]}}

If no clear microbe change reported, return:
{{"disease": "disease name", "taxa_enriched": [], "taxa_depleted": []}}

Paper text:
{text}

JSON:"""
'''

# %%
#rigid prompt

"""
Extract all microbe-disease relationships from this paper.
For each microbe with a reported change, record:
- taxon_name: exact name from the paper
- direction: "increased" or "decreased"

Rules:
- Only read Abstract, Results, and Discussion sections. Ignore Methods, figures, and tables.
- Do NOT include microbes only mentioned in citations or background literature.
- Do NOT infer directionality if the paper does not explicitly state it.
- Do NOT include microbes that were experimentally administered (e.g. probiotics given as treatment).
- Be forgiving on taxon name spelling but strict on directionality — if direction is ambiguous, omit the taxon.

Return ONLY valid JSON, no commentary:
{{"disease": "disease name", "taxa_enriched": ["taxon1", "taxon2"], "taxa_depleted": ["taxon3", "taxon4"]}}
If no clear microbe changes reported, return:
{{"disease": "disease name", "taxa_enriched": [], "taxa_depleted": []}}
Paper text:
{text}
JSON:
"""

# %%
import json, time, os, csv, re
from datetime import datetime

DATA_PATH = "gold_standard_final_15.json"
os.makedirs("benchmark_results", exist_ok=True)

with open(DATA_PATH, "r") as f:
    papers = json.load(f)

PROMPT_TEMPLATE = '''

'''

def smart_truncate(text):
    for marker in ["References\n", "REFERENCES\n", "Bibliography\n"]:
        idx = text.rfind(marker)
        if idx > 0:
            return text[:idx]
    return text

results = []

for i, paper in enumerate(papers):
    print(f"[{i+1}/{len(papers)}] {paper['title'][:70]}...")

    text = smart_truncate(paper["text"])
    prompt = PROMPT_TEMPLATE.format(text=text)
    start = time.time()

    output = llm.create_chat_completion(
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        max_tokens=2048,
    )
    raw = output["choices"][0]["message"]["content"]
    elapsed = time.time() - start

    try:
        clean = raw
        # strip <think> block if present
        if "</think>" in clean:
            clean = clean.split("</think>")[-1]
        clean = clean.strip()
        if "```json" in clean:
            clean = clean.split("```json")[1].split("```")[0]
        elif "```" in clean:
            clean = clean.split("```")[1].split("```")[0]
        parsed = json.loads(clean.strip())
    except:
        parsed = {"disease": paper["disease"], "taxa_enriched": [], "taxa_depleted": [], "parse_error": True}

    results.append({
        "title": paper["title"],
        "disease": paper["disease"],
        "in_gold_standard": paper["in_gold_standard"],
        "expected_enriched": paper.get("taxa_enriched", ""),
        "expected_depleted": paper.get("taxa_depleted", ""),
        "predicted_enriched": ", ".join(parsed.get("taxa_enriched", [])),
        "predicted_depleted": ", ".join(parsed.get("taxa_depleted", [])),
        "predicted_disease": parsed.get("disease", ""),
        "time_seconds": round(elapsed, 2),
        "parse_error": parsed.get("parse_error", False),
    })

    print(f"  enriched: {parsed.get('taxa_enriched', [])}")
    print(f"  depleted: {parsed.get('taxa_depleted', [])}")
    print(f"  {elapsed:.1f}s")

print(f"\nDone. {len(results)} papers.")
# Out:
# [1/15] Intestinal flora induces depression by mediating the dysregulation of ...
#   enriched: []
#   depleted: []
#   21.5s
# [2/15] Gut microbes exacerbate systemic inflammation and behavior disorders i...
#   enriched: []
#   depleted: []
#   32.4s
# [3/15] Alterations in gut microbiota and metabolomic profiles in acute stroke...
#   enriched: ['Firmicutes', 'Faecalibacterium', 'Agathobacter', 'Blautia', 'Barnesiella', 'Dialister', 'Ruminococcus']
#   depleted: ['Bacteroidota', 'Bacteroides', 'Escherichia-Shigella']
#   31.9s
# [4/15] Gut microbiome dysbiosis across early Parkinson's disease, REM sleep b...
#   enriched: ['Collinsella', 'Desulfovibrio', 'Oscillospiraceae_UCG-005', 'Oscillospiraceae_UCG-002', 'Akkermansia', 'UBA1819', 'Family_XIII_AD3011_group', 'Uncultured_Oscillospiraceae_g061']
#   depleted: ['Butyricicoccus', 'Faecalibacterium', 'Roseburia', 'Lachnospiraceae_ND3007_group', 'Lachnospira', '[Eubacterium]_ventriosum_group', 'Lachnospiraceae', 'Lachnoclostridium', '[Ruminococcus]_torques_group']
#   47.3s
# [5/15] The gut microbiota in multiple sclerosis varies with disease activity....
#   enriched: []
#   depleted: []
#   58.7s
# [6/15] Gut Microbial Ecosystem in Parkinson Disease: New Clinicobiological In...
#   enriched: []
#   depleted: []
#   10.5s
# [7/15] Dysbiosis of gut microbiota in a selected population of Parkinson's pa...
#   enriched: ['Lactobacillaceae', 'Enterobacteriaceae', 'Enterococcaceae']
#   depleted: ['Lachnospiraceae']
#   8.9s
# [8/15] Gut microbiota distinguishes aging hispanics with Alzheimer's disease:...
#   enriched: []
#   depleted: []
#   56.1s
# [9/15] Examining the complex Interplay between gut microbiota abundance and s...
#   enriched: ['Fusobacteria', 'Acidobacteria', 'Enterobacter', 'Clostridium', 'Veillonella', 'Dialister', 'Turicibacter', 'Acidaminococcus', 'Tenericutes']
#   depleted: ['Prevotella', 'Lactobacillus', 'Butyricimonas']
#   24.6s
# [10/15] Characterizing Gut Microbiota in Older Chinese Adults with Cognitive I...
#   enriched: []
#   depleted: ['Megamonas', 'Blautia', 'Veillonella']
#   14.5s
# [11/15] Gut microbiome, cognitive function and brain structure: a multi-omics ...
#   enriched: ['Dorea longicatena', 'Firmicutes']
#   depleted: ['Odoribacter', 'Butyricimonas', 'Bacteroides', 'Bacteroidetes']
#   21.8s
# [12/15] Retrospective analysis of diet and gut microbiota diversity and clinic...
#   enriched: ['Firmicutes', 'Actinobacteria', 'Proteobacteria', 'Bifidobacteriaceae', 'Lachnospiraceae', 'Enterobacteriaceae', 'Streptococcaceae', 'Oxalobacteraceae', 'Acetobacteraceae', 'Coriobacteriaceae', 'Christensenellaceae', 'Tissierellaceae', 'Rhodospirillaceae', 'Comamonadaceae', 'Porphyromonadaceae', 'Porphyromonas', 'Bifidobacterium', 'Lactococcus', 'Enterobacter', 'Acetobacter', 'Oxalobacter', 'Lachnospira', 'Enterococcus', 'Rhodospirillum', 'Gemmiger', 'Collinsella', 'Butyricimonas', 'Alistipes', 'Odoribacter']
#   depleted: ['Bacteroidetes', 'Veillonellaceae', 'Mitsuokella']
#   36.8s
# [13/15] Changes in the Gut Microbiome and Predicted Functional Metabolic Effec...
#   enriched: ['Proteobacteria', 'Synergistetes', 'Gammaproteobacteria', 'Enterobacterales', 'Enterobacteriaceae', 'Synergistia']
#   depleted: ['Clostridia', 'Clostridiales', 'Lachnospiraceae', 'Roseburia', 'Kineothrix', 'Agathobaculum', 'Colidextribacter', 'Intestinibacter']
#   30.2s
# [14/15] Nutritional Intake and Gut Microbiome Composition Predict Parkinson's ...
#   enriched: ['Lactobacillaceae', 'Lactobacillales', 'Enterobacteriaceae', 'Bifidobacterium', 'Butyricimonas']
#   depleted: ['Lachnospiraceae ND3007 group', 'Butyricicoccus', 'Fusicatenibacter']
#   27.7s
# [15/15] Gut Microbiome Distinguishes Patients With Epilepsy From Healthy Indiv...
#   enriched: []
#   depleted: []
#   52.3s
#
# Done. 15 papers.

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

json_path = f"benchmark_results/qwopus_updatedPrompt_6April_{timestamp}.json"
with open(json_path, "w") as f:
    json.dump(results, f, indent=2)

csv_path = f"benchmark_results/qwopus_{timestamp}.csv"
cols = ["title", "disease", "in_gold_standard",
        "expected_enriched", "expected_depleted",
        "predicted_enriched", "predicted_depleted",
        "predicted_disease", "time_seconds", "parse_error"]

with open(csv_path, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=cols)
    writer.writeheader()
    writer.writerows(results)

print(f"JSON: {json_path}")
print(f"CSV:  {csv_path}")

# %%
#if want to run eval on custom file
import csv
import re
with open("benchmark_results/qwopus_cot_updatedprompt_20260329_050629.csv", "r") as f:
    results = list(csv.DictReader(f))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def parse_taxa(val):
    if not val or str(val) == "NaN" or str(val) == "nan":
        return []
    taxa = re.split(r'[,;]', str(val))
    cleaned = []
    for t in taxa:
        t = re.sub(r'\(.*?\)', '', t).strip().lower()
        t = re.sub(r'p\s*[<>=]\s*[\d.]+', '', t).strip()
        t = t.strip('.) ')
        if t and t != "nan" and len(t) > 2:
            cleaned.append(t)
    return cleaned

def match_taxa(predicted, expected):
    if not predicted and not expected:
        return [], []
    if not predicted:
        return [], expected
    if not expected:
        return [(p, "N/A (no expected)", 0.0) for p in predicted], []

    all_names = predicted + expected
    tfidf = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4)).fit_transform(all_names)
    sim = cosine_similarity(tfidf[:len(predicted)], tfidf[len(predicted):])

    matches = []
    matched_expected_idx = set()
    for i, pred in enumerate(predicted):
        best_j = sim[i].argmax()
        score = round(float(sim[i][best_j]), 3)
        matches.append((pred, expected[best_j], score))
        if score >= 0.5:
            matched_expected_idx.add(best_j)

    missed = [expected[j] for j in range(len(expected)) if j not in matched_expected_idx]
    return matches, missed

for r in results:
    print(f"\n{'='*60}")
    print(f"{r['title'][:70]}")
    print(f"Disease: {r['disease']} | Gold: {r['in_gold_standard']}")

    pred_enr = parse_taxa(r["predicted_enriched"])
    pred_dep = parse_taxa(r["predicted_depleted"])
    exp_enr = parse_taxa(r["expected_enriched"])
    exp_dep = parse_taxa(r["expected_depleted"])

    enr_matches, enr_missed = match_taxa(pred_enr, exp_enr)
    dep_matches, dep_missed = match_taxa(pred_dep, exp_dep)

    if enr_matches:
        print("  ENRICHED:")
        for pred, exp, score in enr_matches:
            flag = "✅" if score >= 0.5 else "❌"
            print(f"    {flag} {pred} → {exp}  sim={score}")
    if enr_missed:
        print("  MISSED ENRICHED:")
        for m in enr_missed:
            print(f"    ⚠️  {m}")

    if dep_matches:
        print("  DEPLETED:")
        for pred, exp, score in dep_matches:
            flag = "✅" if score >= 0.5 else "❌"
            print(f"    {flag} {pred} → {exp}  sim={score}")
    if dep_missed:
        print("  MISSED DEPLETED:")
        for m in dep_missed:
            print(f"    ⚠️  {m}")

    if not enr_matches and not dep_matches and not enr_missed and not dep_missed:
        print("  (no predictions, no expected)")

    tp = sum(1 for _, _, s in enr_matches + dep_matches if s >= 0.5)
    fp = sum(1 for _, _, s in enr_matches + dep_matches if s < 0.5)
    fn = len(enr_missed) + len(dep_missed)
    print(f"  → TP={tp}  FP={fp}  FN={fn}")
# Out:
# ============================================================
# Intestinal flora induces depression by mediating the dysregulation of
# Disease: Stroke | Gold: No
#   MISSED ENRICHED:
#     ⚠️  g_erysipelotrichaceae ucg-003
#   → TP=0  FP=0  FN=1
#
# ============================================================
# Gut microbes exacerbate systemic inflammation and behavior disorders i
# Disease: Other | Gold: Yes
#   ENRICHED:
#     ✅ porphyromonas → porphyromonas  sim=1.0
#     ✅ akkermansia → akkermansia  sim=1.0
#     ✅ eubacterium siraeum → eubacterium siraeum  sim=1.0
#     ✅ akkermansia muciniphila → akkermansia muciniphila  sim=1.0
#     ✅ fusobacterium varium → fusobacterium varium  sim=1.0
#     ✅ megasphaera elsdenii → megasphaera elsdenii  sim=1.0
#     ✅ clostridium aldenense → clostridium aldenense  sim=1.0
#     ✅ bacteroides sp. om05-12 → bacteroides sp. om05-12  sim=1.0
#     ✅ streptococcus sp. a12 → streptococcus sp. a12  sim=1.0
#   DEPLETED:
#     ✅ sutterella → sutterella  sim=1.0
#     ✅ roseburia faecis → roseburia faecis  sim=1.0
#     ✅ eubacterium eligens → eubacterium eligens  sim=1.0
#     ✅ sutterella parvirubra → sutterella parvirubra  sim=1.0
#   → TP=13  FP=0  FN=0
#
# ============================================================
# Alterations in gut microbiota and metabolomic profiles in acute stroke
# Disease: Stroke | Gold: Yes
#   ENRICHED:
#     ✅ firmicutes → firmicutes  sim=1.0
#     ✅ faecalibacterium → faecalibacterium  sim=1.0
#     ✅ agathobacter → agathobacter  sim=1.0
#     ❌ blautia → barnesiella  sim=0.081
#     ✅ barnesiella → barnesiella  sim=1.0
#     ❌ dialister → agathobacter  sim=0.122
#     ❌ ruminococcus → firmicutes  sim=0.063
#   DEPLETED:
#     ❌ proteobacteria → bacteroides  sim=0.23
#     ✅ bacteroidota → bacteroides  sim=0.557
#     ✅ bacteroides → bacteroides  sim=1.0
#     ✅ escherichia-shigella → escherichia-shigella  sim=1.0
#     ❌ megamonas → bacteroides  sim=0.024
#   → TP=7  FP=5  FN=0
#
# ============================================================
# Gut microbiome dysbiosis across early Parkinson's disease, REM sleep b
# Disease: Parkinson’s disease (PD) | Gold: No
#   MISSED ENRICHED:
#     ⚠️  clostridia_ucg-014
#     ⚠️  akkermansia
#     ⚠️  collinsella
#   MISSED DEPLETED:
#     ⚠️  roseburia
#     ⚠️  faecalibacterium
#     ⚠️  butyricicoccus
#   → TP=0  FP=0  FN=6
#
# ============================================================
# The gut microbiota in multiple sclerosis varies with disease activity.
# Disease: Multiple sclerosis (MS) | Gold: Yes
#   MISSED ENRICHED:
#     ⚠️  dysosmobacter
#     ⚠️  flavonifractor
#     ⚠️  lawsonibacter
#     ⚠️  hungatella
#     ⚠️  bilophila
#     ⚠️  gordonibacter
#     ⚠️  anaerobutyricum
#     ⚠️  pseudoflavonifractor
#     ⚠️  blautia
#     ⚠️  anaerotruncus
#     ⚠️  erysipelatoclostridium
#     ⚠️  ruminococcus
#     ⚠️  selimonas
#     ⚠️  coprobacillus
#     ⚠️  clostridium
#   MISSED DEPLETED:
#     ⚠️  haemophilus
#     ⚠️  veillonella
#     ⚠️  victivallis
#     ⚠️  bifidobacterium
#     ⚠️  streptococcus
#   → TP=0  FP=0  FN=20
#
# ============================================================
# Gut Microbial Ecosystem in Parkinson Disease: New Clinicobiological In
# Disease: Parkinson’s disease (PD) | Gold: No
#   MISSED ENRICHED:
#     ⚠️  bacteroides fragilis
#     ⚠️  lactobacillus acidophilus
#     ⚠️  unclassified megasphaera
#     ⚠️  and unclassified gammaproteobacteria. five genera were significantly increased in pd (cloacibacillus
#     ⚠️  catabacter
#     ⚠️  christensenella
#     ⚠️  butyrivibrio
#     ⚠️  and bifidobacterium
#   → TP=0  FP=0  FN=8
#
# ============================================================
# Dysbiosis of gut microbiota in a selected population of Parkinson's pa
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ✅ lactobacillaceae → lactobacillaceae  sim=1.0
#     ✅ enterobacteriaceae → enterobacteriaceae and enterococcaceae families  sim=0.717
#     ✅ enterococcaceae → enterobacteriaceae and enterococcaceae families  sim=0.694
#   DEPLETED:
#     ✅ lachnospiraceae → lachnospiraceae  sim=1.0
#   → TP=4  FP=0  FN=0
#
# ============================================================
# Gut microbiota distinguishes aging hispanics with Alzheimer's disease:
# Disease: Alzheimer’s disease (AD) | Gold: No
#   (no predictions, no expected)
#   → TP=0  FP=0  FN=0
#
# ============================================================
# Examining the complex Interplay between gut microbiota abundance and s
# Disease: Amyotrophic lateral sclerosis (ALS) | Gold: No
#   ENRICHED:
#     ❌ fusobacteria → N/A (no expected)  sim=0.0
#     ❌ acidobacteria → N/A (no expected)  sim=0.0
#     ❌ tenericutes → N/A (no expected)  sim=0.0
#     ❌ enterobacter → N/A (no expected)  sim=0.0
#     ❌ clostridium → N/A (no expected)  sim=0.0
#     ❌ veillonella → N/A (no expected)  sim=0.0
#     ❌ dialister → N/A (no expected)  sim=0.0
#     ❌ turicibacter → N/A (no expected)  sim=0.0
#     ❌ acidaminococcus → N/A (no expected)  sim=0.0
#     ❌ acidaminococcaceae → N/A (no expected)  sim=0.0
#     ❌ enterobacteriaceae → N/A (no expected)  sim=0.0
#   DEPLETED:
#     ❌ prevotella → N/A (no expected)  sim=0.0
#     ❌ lactobacillus → N/A (no expected)  sim=0.0
#     ❌ butyricimonas → N/A (no expected)  sim=0.0
#   → TP=0  FP=14  FN=0
#
# ============================================================
# Characterizing Gut Microbiota in Older Chinese Adults with Cognitive I
# Disease: nan | Gold: Yes
#   ENRICHED:
#     ✅ pseudomonas → pseudomonas  sim=1.0
#     ✅ stenotrophomonas → stenotrophomonas  sim=1.0
#   MISSED ENRICHED:
#     ⚠️  shigella
#     ⚠️  acidaminococcus
#     ⚠️  synergistes
#     ⚠️  pyramidobacter
#     ⚠️  alistipes
#     ⚠️  fusobacterium
#     ⚠️  aquabacterium
#     ⚠️  sediminibacterium
#   DEPLETED:
#     ❌ megamonas → bacteroides  sim=0.018
#     ❌ blautia → proteobacteria  sim=0.069
#     ❌ veillonella → proteobacteria  sim=0.014
#   MISSED DEPLETED:
#     ⚠️  firmicutes
#     ⚠️  proteobacteria
#     ⚠️  bacteroides
#   → TP=2  FP=3  FN=11
#
# ============================================================
# Gut microbiome, cognitive function and brain structure: a multi-omics
# Disease: Alzheimer’s disease (AD), Dementia | Gold: Yes
#   ENRICHED:
#     ❌ firmicutes → dorea longicatena  sim=0.024
#     ✅ dorea longicatena → dorea longicatena  sim=1.0
#   DEPLETED:
#     ✅ bacteroidetes → bacteroides  sim=0.719
#     ✅ odoribacter → odoribacter  sim=1.0
#     ✅ butyricimonas → butyricimonas  sim=1.0
#     ✅ bacteroides → bacteroides  sim=1.0
#   → TP=5  FP=1  FN=0
#
# ============================================================
# Retrospective analysis of diet and gut microbiota diversity and clinic
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ❌ firmicutes → alistipes  sim=0.076
#     ❌ actinobacteria → acetobacter  sim=0.29
#     ❌ proteobacteria → enterobacter  sim=0.233
#     ✅ bifidobacteriaceae → bifidobacterium  sim=0.707
#     ✅ lachnospiraceae → lachnospira  sim=0.82
#     ✅ enterobacteriaceae → enterobacter  sim=0.76
#     ❌ streptococcaceae → lactococcus  sim=0.306
#     ✅ oxalobacteraceae → oxalobacter  sim=0.77
#     ✅ acetobacteraceae → acetobacter  sim=0.765
#     ❌ coriobacteriaceae → acetobacter  sim=0.225
#     ❌ christensenellaceae → collinsella  sim=0.203
#     ❌ tissierellaceae → collinsella  sim=0.134
#     ✅ rhodospirillaceae → rhodospirillum  sim=0.744
#     ❌ comamonadaceae → porphyromonas  sim=0.131
#     ✅ porphyromonadaceae → porphyromonas  sim=0.765
#     ❌ sphingomonadaceae → porphyromonas  sim=0.179
#     ✅ porphyromonas → porphyromonas  sim=1.0
#     ✅ bifidobacterium → bifidobacterium  sim=1.0
#     ✅ lactococcus → lactococcus  sim=1.0
#     ✅ enterobacter → enterobacter  sim=1.0
#     ✅ acetobacter → acetobacter  sim=1.0
#     ✅ oxalobacter → oxalobacter  sim=1.0
#     ✅ lachnospira → lachnospira  sim=1.0
#     ✅ enterococcus → enterococcus  sim=1.0
#     ✅ rhodospirillum → rhodospirillum  sim=1.0
#     ✅ gemmiger → gemmiger  sim=1.0
#     ✅ collinsella → collinsella  sim=1.0
#     ✅ butyricimonas → butyricimonas  sim=1.0
#     ✅ alistipes → alistipes  sim=1.0
#     ✅ odoribacter → odoribacter  sim=1.0
#   DEPLETED:
#     ❌ bacteroidetes → mitsuokella  sim=0.0
#     ❌ veillonellaceae → mitsuokella  sim=0.101
#     ✅ mitsuokella → mitsuokella  sim=1.0
#   → TP=22  FP=11  FN=0
#
# ============================================================
# Changes in the Gut Microbiome and Predicted Functional Metabolic Effec
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ✅ proteobacteria → proteobacteria  sim=1.0
#     ✅ synergistetes → synergistetes  sim=1.0
#     ✅ gammaproteobacteria → proteobacteria  sim=0.642
#     ❌ enterobacterales → proteobacteria  sim=0.251
#     ❌ enterobacteriaceae → proteobacteria  sim=0.344
#     ✅ synergistia → synergistetes  sim=0.597
#   DEPLETED:
#     ❌ clostridia → roseburia  sim=0.117
#     ❌ clostridiales → colidextribacter  sim=0.075
#     ✅ lachnospiraceae → lachnospiraceae  sim=1.0
#     ✅ roseburia → roseburia  sim=1.0
#     ✅ kineothrix → kineothrix  sim=1.0
#     ✅ agathobaculum → agathobaculum  sim=1.0
#     ✅ colidextribacter → colidextribacter  sim=1.0
#     ✅ intestinibacter → intestinibacter  sim=1.0
#   → TP=10  FP=4  FN=0
#
# ============================================================
# Nutritional Intake and Gut Microbiome Composition Predict Parkinson's
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ❌ lactobacillales → flavonifractor  sim=0.113
#     ❌ lactobacillaceae → flavonifractor  sim=0.116
#     ❌ enterobacteriaceae → bifidobacterium  sim=0.266
#     ✅ bifidobacterium → bifidobacterium  sim=1.0
#     ✅ butyricimonas → butyricimonas  sim=1.0
#   MISSED ENRICHED:
#     ⚠️  candidatus soleaferre
#     ⚠️  faecalibacterium sp. uba1819
#     ⚠️  flavonifractor
#     ⚠️  ruminococcus gnavus
#   DEPLETED:
#     ✅ lachnospiraceae nd3007 group → lachnospiraceae nd3007 group  sim=1.0
#     ✅ butyricicoccus → butyricicoccus  sim=1.0
#     ✅ fusicatenibacter → fusicatenibacter  sim=1.0
#   MISSED DEPLETED:
#     ⚠️  agathobacter
#     ⚠️  erysipelotrichaceae ucg-003
#     ⚠️  eubacterium xylanophilum
#     ⚠️  ruminococcus gauvreauii
#     ⚠️  firmacutes bacterium cag:56
#   → TP=5  FP=3  FN=9
#
# ============================================================
# Gut Microbiome Distinguishes Patients With Epilepsy From Healthy Indiv
# Disease: Epilepsy | Gold: Yes
#   ENRICHED:
#     ✅ proteobacteria → proteobacteria  sim=1.0
#     ✅ actinobacteriota → actinobacteriota  sim=1.0
#     ✅ gammaproteobacteria → proteobacteria  sim=0.588
#     ✅ alphaproteobacteria → proteobacteria  sim=0.604
#     ✅ actinobacteria → actinobacteriota  sim=0.747
#     ❌ enterobacteriales → enterobacteriaceae-unclassified (lda>3  sim=0.373
#     ✅ bifidobacteriales → bifidobacterium (lda>3  sim=0.505
#     ❌ bifidobacteriaceae → bifidobacterium (lda>3  sim=0.49
#     ✅ faecalibacterium → faecalibacterium  sim=1.0
#     ✅ escherichia-shigella → escherichia/shigella (lda>3  sim=0.74
#     ✅ subdoligranulum → subdoligranulum  sim=1.0
#     ✅ enterobacteriaceae-unclassified → enterobacteriaceae-unclassified (lda>3  sim=0.918
#     ✅ halomonas → halomonas (lda>3  sim=0.821
#     ✅ bifidobacterium → bifidobacterium (lda>3  sim=0.791
#   DEPLETED:
#     ✅ bacteroidota → bacteroidota  sim=1.0
#     ❌ bacteroidia → bacteroidota  sim=0.496
#     ❌ negativicutes → megamonas  sim=0.086
#     ❌ bacilli → collinsella  sim=0.115
#     ❌ coriobacteriia → bacteroidota  sim=0.158
#     ✅ lachnospirales → lachnospira (lda>3  sim=0.573
#     ❌ bacteroidales → bacteroides (lda>3  sim=0.444
#     ❌ rikenellaceae → lachnospiraceae-unclassified (lda>3  sim=0.143
#     ✅ bacteroides → bacteroides (lda>3  sim=0.737
#     ✅ megamonas → megamonas  sim=1.0
#     ✅ prevotella → prevotella  sim=1.0
#     ✅ lachnospiraceae-unclassified → lachnospiraceae-unclassified (lda>3  sim=0.92
#     ✅ blautia → blautia (lda>3  sim=0.768
#     ✅ parabacteroides → parabacteroides  sim=1.0
#     ✅ collinsella → collinsella  sim=1.0
#     ✅ lachnospira → lachnospira (lda>3  sim=0.781
#   → TP=22  FP=8  FN=0

# %%
import json, time, os, csv, re
from datetime import datetime

DATA_PATH = "gold_standard_final_15.json"
os.makedirs("benchmark_results", exist_ok=True)

with open(DATA_PATH, "r") as f:
    papers = json.load(f)

PROMPT_TEMPLATE = """Extract all microbe-disease relationships from this paper.

For each microbe with a reported change, record:
- taxon_name: exact name from the paper
- direction: "increased" or "decreased"

Before answering, carefully scan the Abstract, Results, and Discussion sections. Extract at EVERY taxonomic level mentioned (phylum, family, genus, species). Do not miss microbes that appear only in Results tables or only in Discussion. If the same microbe appears at multiple taxonomic levels, include all of them.

Return ONLY valid JSON:
{{"disease": "disease name", "taxa_enriched": ["taxon1", "taxon2"], "taxa_depleted": ["taxon3", "taxon4"]}}

If no clear microbe changes vs healthy control, return:
{{"disease": "disease name", "taxa_enriched": [], "taxa_depleted": []}}

Paper text:
{text}

JSON:"""

def smart_truncate(text):
    for marker in ["References\n", "REFERENCES\n", "Bibliography\n"]:
        idx = text.rfind(marker)
        if idx > 0:
            return text[:idx]
    return text

results = []

for i, paper in enumerate(papers):
    print(f"[{i+1}/{len(papers)}] {paper['title'][:70]}...")

    text = smart_truncate(paper["text"])
    prompt = PROMPT_TEMPLATE.format(text=text)
    start = time.time()

    output = llm.create_chat_completion(
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        max_tokens=4096,
    )
    raw = output["choices"][0]["message"]["content"]
    elapsed = time.time() - start

    try:
        clean = raw
        if "</think>" in clean:
            clean = clean.split("</think>")[-1]
        clean = clean.strip()
        if "```json" in clean:
            clean = clean.split("```json")[1].split("```")[0]
        elif "```" in clean:
            clean = clean.split("```")[1].split("```")[0]
        parsed = json.loads(clean.strip())
    except:
        parsed = {"disease": paper["disease"], "taxa_enriched": [], "taxa_depleted": [], "parse_error": True}

    results.append({
        "title": paper["title"],
        "disease": paper["disease"],
        "in_gold_standard": paper["in_gold_standard"],
        "expected_enriched": paper.get("taxa_enriched", ""),
        "expected_depleted": paper.get("taxa_depleted", ""),
        "predicted_enriched": ", ".join(parsed.get("taxa_enriched", [])),
        "predicted_depleted": ", ".join(parsed.get("taxa_depleted", [])),
        "predicted_disease": parsed.get("disease", ""),
        "time_seconds": round(elapsed, 2),
        "parse_error": parsed.get("parse_error", False),
    })

    print(f"  enriched: {parsed.get('taxa_enriched', [])}")
    print(f"  depleted: {parsed.get('taxa_depleted', [])}")
    print(f"  {elapsed:.1f}s")

print(f"\nDone. {len(results)} papers.")
# Out:
# [1/15] Intestinal flora induces depression by mediating the dysregulation of ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 45
#      42 prompt = PROMPT_TEMPLATE.format(text=text)
#      43 start = time.time()
# ---> 45 output = llm.create_chat_completion(
#      46     messages=[{"role": "user", "content": prompt}],
#      47     temperature=0,
#      48     max_tokens=4096,
#      49 )
#      50 raw = output["choices"][0]["message"]["content"]
#      51 elapsed = time.time() - start
#
# NameError: name 'llm' is not defined

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

json_path = f"benchmark_results/qwopus_cot_updatedprompt_{timestamp}.json"
with open(json_path, "w") as f:
    json.dump(results, f, indent=2)

csv_path = f"benchmark_results/qwopus_cot_updatedprompt_{timestamp}.csv"
cols = ["title", "disease", "in_gold_standard",
        "expected_enriched", "expected_depleted",
        "predicted_enriched", "predicted_depleted",
        "predicted_disease", "time_seconds", "parse_error"]

with open(csv_path, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=cols)
    writer.writeheader()
    writer.writerows(results)

print(f"JSON: {json_path}")
print(f"CSV:  {csv_path}")
# Out:
# JSON: benchmark_results/qwopus_cot_updatedprompt_20260329_050629.json
# CSV:  benchmark_results/qwopus_cot_updatedprompt_20260329_050629.csv

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def parse_taxa(val):
    if not val or str(val) == "NaN" or str(val) == "nan":
        return []
    taxa = re.split(r'[,;]', str(val))
    cleaned = []
    for t in taxa:
        t = re.sub(r'\(.*?\)', '', t).strip().lower()
        t = re.sub(r'p\s*[<>=]\s*[\d.]+', '', t).strip()
        t = t.strip('.) ')
        if t and t != "nan" and len(t) > 2:
            cleaned.append(t)
    return cleaned

def match_taxa(predicted, expected):
    if not predicted and not expected:
        return [], []
    if not predicted:
        return [], expected
    if not expected:
        return [(p, "N/A (no expected)", 0.0) for p in predicted], []

    all_names = predicted + expected
    tfidf = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4)).fit_transform(all_names)
    sim = cosine_similarity(tfidf[:len(predicted)], tfidf[len(predicted):])

    matches = []
    matched_expected_idx = set()
    for i, pred in enumerate(predicted):
        best_j = sim[i].argmax()
        score = round(float(sim[i][best_j]), 3)
        matches.append((pred, expected[best_j], score))
        if score >= 0.5:
            matched_expected_idx.add(best_j)

    missed = [expected[j] for j in range(len(expected)) if j not in matched_expected_idx]
    return matches, missed

total_tp = total_fp = total_fn = 0

for r in results:
    print(f"\n{'='*60}")
    print(f"{r['title'][:70]}")
    print(f"Disease: {r['disease']} | Gold: {r['in_gold_standard']}")

    pred_enr = parse_taxa(r["predicted_enriched"])
    pred_dep = parse_taxa(r["predicted_depleted"])
    exp_enr = parse_taxa(r["expected_enriched"])
    exp_dep = parse_taxa(r["expected_depleted"])

    enr_matches, enr_missed = match_taxa(pred_enr, exp_enr)
    dep_matches, dep_missed = match_taxa(pred_dep, exp_dep)

    if enr_matches:
        print("  ENRICHED:")
        for pred, exp, score in enr_matches:
            flag = "✅" if score >= 0.5 else "❌"
            print(f"    {flag} {pred} → {exp}  sim={score}")
    if enr_missed:
        print("  MISSED ENRICHED:")
        for m in enr_missed:
            print(f"    ⚠️  {m}")

    if dep_matches:
        print("  DEPLETED:")
        for pred, exp, score in dep_matches:
            flag = "✅" if score >= 0.5 else "❌"
            print(f"    {flag} {pred} → {exp}  sim={score}")
    if dep_missed:
        print("  MISSED DEPLETED:")
        for m in dep_missed:
            print(f"    ⚠️  {m}")

    if not enr_matches and not dep_matches and not enr_missed and not dep_missed:
        print("  (no predictions, no expected)")

    tp = sum(1 for _, _, s in enr_matches + dep_matches if s >= 0.5)
    fp = sum(1 for _, _, s in enr_matches + dep_matches if s < 0.5)
    fn = len(enr_missed) + len(dep_missed)
    total_tp += tp
    total_fp += fp
    total_fn += fn
    print(f"  → TP={tp}  FP={fp}  FN={fn}")

p = total_tp / (total_tp + total_fp) if (total_tp + total_fp) else 0
r = total_tp / (total_tp + total_fn) if (total_tp + total_fn) else 0
f1 = 2 * p * r / (p + r) if (p + r) else 0

print(f"\n{'='*60}")
print(f"OVERALL — Qwopus CoT")
print(f"TP={total_tp}  FP={total_fp}  FN={total_fn}")
print(f"Precision: {p:.3f}")
print(f"Recall:    {r:.3f}")
print(f"F1:        {f1:.3f}")
# Out:
# ============================================================
# Intestinal flora induces depression by mediating the dysregulation of
# Disease: Stroke | Gold: No
#   MISSED ENRICHED:
#     ⚠️  g_erysipelotrichaceae ucg-003
#   → TP=0  FP=0  FN=1
#
# ============================================================
# Gut microbes exacerbate systemic inflammation and behavior disorders i
# Disease: Other | Gold: Yes
#   ENRICHED:
#     ✅ porphyromonas → porphyromonas  sim=1.0
#     ✅ akkermansia → akkermansia  sim=1.0
#     ✅ eubacterium siraeum → eubacterium siraeum  sim=1.0
#     ✅ akkermansia muciniphila → akkermansia muciniphila  sim=1.0
#     ✅ fusobacterium varium → fusobacterium varium  sim=1.0
#     ✅ megasphaera elsdenii → megasphaera elsdenii  sim=1.0
#     ✅ clostridium aldenense → clostridium aldenense  sim=1.0
#     ✅ bacteroides sp. om05-12 → bacteroides sp. om05-12  sim=1.0
#     ✅ streptococcus sp. a12 → streptococcus sp. a12  sim=1.0
#   DEPLETED:
#     ✅ sutterella → sutterella  sim=1.0
#     ✅ roseburia faecis → roseburia faecis  sim=1.0
#     ✅ eubacterium eligens → eubacterium eligens  sim=1.0
#     ✅ sutterella parvirubra → sutterella parvirubra  sim=1.0
#   → TP=13  FP=0  FN=0
#
# ============================================================
# Alterations in gut microbiota and metabolomic profiles in acute stroke
# Disease: Stroke | Gold: Yes
#   ENRICHED:
#     ✅ firmicutes → firmicutes  sim=1.0
#     ✅ faecalibacterium → faecalibacterium  sim=1.0
#     ✅ agathobacter → agathobacter  sim=1.0
#     ❌ blautia → barnesiella  sim=0.081
#     ✅ barnesiella → barnesiella  sim=1.0
#     ❌ dialister → agathobacter  sim=0.122
#     ❌ ruminococcus → firmicutes  sim=0.063
#   DEPLETED:
#     ❌ proteobacteria → bacteroides  sim=0.23
#     ✅ bacteroidota → bacteroides  sim=0.557
#     ✅ bacteroides → bacteroides  sim=1.0
#     ✅ escherichia-shigella → escherichia-shigella  sim=1.0
#     ❌ megamonas → bacteroides  sim=0.024
#   → TP=7  FP=5  FN=0
#
# ============================================================
# Gut microbiome dysbiosis across early Parkinson's disease, REM sleep b
# Disease: Parkinson’s disease (PD) | Gold: No
#   MISSED ENRICHED:
#     ⚠️  clostridia_ucg-014
#     ⚠️  akkermansia
#     ⚠️  collinsella
#   MISSED DEPLETED:
#     ⚠️  roseburia
#     ⚠️  faecalibacterium
#     ⚠️  butyricicoccus
#   → TP=0  FP=0  FN=6
#
# ============================================================
# The gut microbiota in multiple sclerosis varies with disease activity.
# Disease: Multiple sclerosis (MS) | Gold: Yes
#   MISSED ENRICHED:
#     ⚠️  dysosmobacter
#     ⚠️  flavonifractor
#     ⚠️  lawsonibacter
#     ⚠️  hungatella
#     ⚠️  bilophila
#     ⚠️  gordonibacter
#     ⚠️  anaerobutyricum
#     ⚠️  pseudoflavonifractor
#     ⚠️  blautia
#     ⚠️  anaerotruncus
#     ⚠️  erysipelatoclostridium
#     ⚠️  ruminococcus
#     ⚠️  selimonas
#     ⚠️  coprobacillus
#     ⚠️  clostridium
#   MISSED DEPLETED:
#     ⚠️  haemophilus
#     ⚠️  veillonella
#     ⚠️  victivallis
#     ⚠️  bifidobacterium
#     ⚠️  streptococcus
#   → TP=0  FP=0  FN=20
#
# ============================================================
# Gut Microbial Ecosystem in Parkinson Disease: New Clinicobiological In
# Disease: Parkinson’s disease (PD) | Gold: No
#   MISSED ENRICHED:
#     ⚠️  bacteroides fragilis
#     ⚠️  lactobacillus acidophilus
#     ⚠️  unclassified megasphaera
#     ⚠️  and unclassified gammaproteobacteria. five genera were significantly increased in pd (cloacibacillus
#     ⚠️  catabacter
#     ⚠️  christensenella
#     ⚠️  butyrivibrio
#     ⚠️  and bifidobacterium
#   → TP=0  FP=0  FN=8
#
# ============================================================
# Dysbiosis of gut microbiota in a selected population of Parkinson's pa
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ✅ lactobacillaceae → lactobacillaceae  sim=1.0
#     ✅ enterobacteriaceae → enterobacteriaceae and enterococcaceae families  sim=0.717
#     ✅ enterococcaceae → enterobacteriaceae and enterococcaceae families  sim=0.694
#   DEPLETED:
#     ✅ lachnospiraceae → lachnospiraceae  sim=1.0
#   → TP=4  FP=0  FN=0
#
# ============================================================
# Gut microbiota distinguishes aging hispanics with Alzheimer's disease:
# Disease: Alzheimer’s disease (AD) | Gold: No
#   (no predictions, no expected)
#   → TP=0  FP=0  FN=0
#
# ============================================================
# Examining the complex Interplay between gut microbiota abundance and s
# Disease: Amyotrophic lateral sclerosis (ALS) | Gold: No
#   ENRICHED:
#     ❌ fusobacteria → N/A (no expected)  sim=0.0
#     ❌ acidobacteria → N/A (no expected)  sim=0.0
#     ❌ tenericutes → N/A (no expected)  sim=0.0
#     ❌ enterobacter → N/A (no expected)  sim=0.0
#     ❌ clostridium → N/A (no expected)  sim=0.0
#     ❌ veillonella → N/A (no expected)  sim=0.0
#     ❌ dialister → N/A (no expected)  sim=0.0
#     ❌ turicibacter → N/A (no expected)  sim=0.0
#     ❌ acidaminococcus → N/A (no expected)  sim=0.0
#     ❌ acidaminococcaceae → N/A (no expected)  sim=0.0
#     ❌ enterobacteriaceae → N/A (no expected)  sim=0.0
#   DEPLETED:
#     ❌ prevotella → N/A (no expected)  sim=0.0
#     ❌ lactobacillus → N/A (no expected)  sim=0.0
#     ❌ butyricimonas → N/A (no expected)  sim=0.0
#   → TP=0  FP=14  FN=0
#
# ============================================================
# Characterizing Gut Microbiota in Older Chinese Adults with Cognitive I
# Disease: nan | Gold: Yes
#   ENRICHED:
#     ✅ pseudomonas → pseudomonas  sim=1.0
#     ✅ stenotrophomonas → stenotrophomonas  sim=1.0
#   MISSED ENRICHED:
#     ⚠️  shigella
#     ⚠️  acidaminococcus
#     ⚠️  synergistes
#     ⚠️  pyramidobacter
#     ⚠️  alistipes
#     ⚠️  fusobacterium
#     ⚠️  aquabacterium
#     ⚠️  sediminibacterium
#   DEPLETED:
#     ❌ megamonas → bacteroides  sim=0.018
#     ❌ blautia → proteobacteria  sim=0.069
#     ❌ veillonella → proteobacteria  sim=0.014
#   MISSED DEPLETED:
#     ⚠️  firmicutes
#     ⚠️  proteobacteria
#     ⚠️  bacteroides
#   → TP=2  FP=3  FN=11
#
# ============================================================
# Gut microbiome, cognitive function and brain structure: a multi-omics
# Disease: Alzheimer’s disease (AD), Dementia | Gold: Yes
#   ENRICHED:
#     ❌ firmicutes → dorea longicatena  sim=0.024
#     ✅ dorea longicatena → dorea longicatena  sim=1.0
#   DEPLETED:
#     ✅ bacteroidetes → bacteroides  sim=0.719
#     ✅ odoribacter → odoribacter  sim=1.0
#     ✅ butyricimonas → butyricimonas  sim=1.0
#     ✅ bacteroides → bacteroides  sim=1.0
#   → TP=5  FP=1  FN=0
#
# ============================================================
# Retrospective analysis of diet and gut microbiota diversity and clinic
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ❌ firmicutes → alistipes  sim=0.076
#     ❌ actinobacteria → acetobacter  sim=0.29
#     ❌ proteobacteria → enterobacter  sim=0.233
#     ✅ bifidobacteriaceae → bifidobacterium  sim=0.707
#     ✅ lachnospiraceae → lachnospira  sim=0.82
#     ✅ enterobacteriaceae → enterobacter  sim=0.76
#     ❌ streptococcaceae → lactococcus  sim=0.306
#     ✅ oxalobacteraceae → oxalobacter  sim=0.77
#     ✅ acetobacteraceae → acetobacter  sim=0.765
#     ❌ coriobacteriaceae → acetobacter  sim=0.225
#     ❌ christensenellaceae → collinsella  sim=0.203
#     ❌ tissierellaceae → collinsella  sim=0.134
#     ✅ rhodospirillaceae → rhodospirillum  sim=0.744
#     ❌ comamonadaceae → porphyromonas  sim=0.131
#     ✅ porphyromonadaceae → porphyromonas  sim=0.765
#     ❌ sphingomonadaceae → porphyromonas  sim=0.179
#     ✅ porphyromonas → porphyromonas  sim=1.0
#     ✅ bifidobacterium → bifidobacterium  sim=1.0
#     ✅ lactococcus → lactococcus  sim=1.0
#     ✅ enterobacter → enterobacter  sim=1.0
#     ✅ acetobacter → acetobacter  sim=1.0
#     ✅ oxalobacter → oxalobacter  sim=1.0
#     ✅ lachnospira → lachnospira  sim=1.0
#     ✅ enterococcus → enterococcus  sim=1.0
#     ✅ rhodospirillum → rhodospirillum  sim=1.0
#     ✅ gemmiger → gemmiger  sim=1.0
#     ✅ collinsella → collinsella  sim=1.0
#     ✅ butyricimonas → butyricimonas  sim=1.0
#     ✅ alistipes → alistipes  sim=1.0
#     ✅ odoribacter → odoribacter  sim=1.0
#   DEPLETED:
#     ❌ bacteroidetes → mitsuokella  sim=0.0
#     ❌ veillonellaceae → mitsuokella  sim=0.101
#     ✅ mitsuokella → mitsuokella  sim=1.0
#   → TP=22  FP=11  FN=0
#
# ============================================================
# Changes in the Gut Microbiome and Predicted Functional Metabolic Effec
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ✅ proteobacteria → proteobacteria  sim=1.0
#     ✅ synergistetes → synergistetes  sim=1.0
#     ✅ gammaproteobacteria → proteobacteria  sim=0.642
#     ❌ enterobacterales → proteobacteria  sim=0.251
#     ❌ enterobacteriaceae → proteobacteria  sim=0.344
#     ✅ synergistia → synergistetes  sim=0.597
#   DEPLETED:
#     ❌ clostridia → roseburia  sim=0.117
#     ❌ clostridiales → colidextribacter  sim=0.075
#     ✅ lachnospiraceae → lachnospiraceae  sim=1.0
#     ✅ roseburia → roseburia  sim=1.0
#     ✅ kineothrix → kineothrix  sim=1.0
#     ✅ agathobaculum → agathobaculum  sim=1.0
#     ✅ colidextribacter → colidextribacter  sim=1.0
#     ✅ intestinibacter → intestinibacter  sim=1.0
#   → TP=10  FP=4  FN=0
#
# ============================================================
# Nutritional Intake and Gut Microbiome Composition Predict Parkinson's
# Disease: Parkinson’s disease (PD) | Gold: Yes
#   ENRICHED:
#     ❌ lactobacillales → flavonifractor  sim=0.113
#     ❌ lactobacillaceae → flavonifractor  sim=0.116
#     ❌ enterobacteriaceae → bifidobacterium  sim=0.266
#     ✅ bifidobacterium → bifidobacterium  sim=1.0
#     ✅ butyricimonas → butyricimonas  sim=1.0
#   MISSED ENRICHED:
#     ⚠️  candidatus soleaferre
#     ⚠️  faecalibacterium sp. uba1819
#     ⚠️  flavonifractor
#     ⚠️  ruminococcus gnavus
#   DEPLETED:
#     ✅ lachnospiraceae nd3007 group → lachnospiraceae nd3007 group  sim=1.0
#     ✅ butyricicoccus → butyricicoccus  sim=1.0
#     ✅ fusicatenibacter → fusicatenibacter  sim=1.0
#   MISSED DEPLETED:
#     ⚠️  agathobacter
#     ⚠️  erysipelotrichaceae ucg-003
#     ⚠️  eubacterium xylanophilum
#     ⚠️  ruminococcus gauvreauii
#     ⚠️  firmacutes bacterium cag:56
#   → TP=5  FP=3  FN=9
#
# ============================================================
# Gut Microbiome Distinguishes Patients With Epilepsy From Healthy Indiv
# Disease: Epilepsy | Gold: Yes
#   ENRICHED:
#     ✅ proteobacteria → proteobacteria  sim=1.0
#     ✅ actinobacteriota → actinobacteriota  sim=1.0
#     ✅ gammaproteobacteria → proteobacteria  sim=0.588
#     ✅ alphaproteobacteria → proteobacteria  sim=0.604
#     ✅ actinobacteria → actinobacteriota  sim=0.747
#     ❌ enterobacteriales → enterobacteriaceae-unclassified (lda>3  sim=0.373
#     ✅ bifidobacteriales → bifidobacterium (lda>3  sim=0.505
#     ❌ bifidobacteriaceae → bifidobacterium (lda>3  sim=0.49
#     ✅ faecalibacterium → faecalibacterium  sim=1.0
#     ✅ escherichia-shigella → escherichia/shigella (lda>3  sim=0.74
#     ✅ subdoligranulum → subdoligranulum  sim=1.0
#     ✅ enterobacteriaceae-unclassified → enterobacteriaceae-unclassified (lda>3  sim=0.918
#     ✅ halomonas → halomonas (lda>3  sim=0.821
#     ✅ bifidobacterium → bifidobacterium (lda>3  sim=0.791
#   DEPLETED:
#     ✅ bacteroidota → bacteroidota  sim=1.0
#     ❌ bacteroidia → bacteroidota  sim=0.496
#     ❌ negativicutes → megamonas  sim=0.086
#     ❌ bacilli → collinsella  sim=0.115
#     ❌ coriobacteriia → bacteroidota  sim=0.158
#     ✅ lachnospirales → lachnospira (lda>3  sim=0.573
#     ❌ bacteroidales → bacteroides (lda>3  sim=0.444
#     ❌ rikenellaceae → lachnospiraceae-unclassified (lda>3  sim=0.143
#     ✅ bacteroides → bacteroides (lda>3  sim=0.737
#     ✅ megamonas → megamonas  sim=1.0
#     ✅ prevotella → prevotella  sim=1.0
#     ✅ lachnospiraceae-unclassified → lachnospiraceae-unclassified (lda>3  sim=0.92
#     ✅ blautia → blautia (lda>3  sim=0.768
#     ✅ parabacteroides → parabacteroides  sim=1.0
#     ✅ collinsella → collinsella  sim=1.0
#     ✅ lachnospira → lachnospira (lda>3  sim=0.781
#   → TP=22  FP=8  FN=0
#
# ============================================================
# OVERALL — Qwopus CoT
# TP=90  FP=49  FN=55
# Precision: 0.647
# Recall:    0.621
# F1:        0.634
